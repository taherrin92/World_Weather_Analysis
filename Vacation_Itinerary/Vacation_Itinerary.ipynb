# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    Unnamed: 0                 City Country  Max Temp Current Description  \
# 0           8  Province du Boulgou      BF    77.288    scattered clouds
# 1          14          Andranomena      MG    74.876       broken clouds
# 2          22             Kom Ombo      EG    72.608       broken clouds
# 3          42             San José      CO    71.042          light rain
# 4          50               Mbutuý      PY    70.898     overcast clouds
#
#          Lat        Lng                Hotel Name
# 0  11.218663  -0.646994    Zourma (Village Bissa)
# 1 -23.466552  43.855126              villa KOTOBE
# 2  24.425944  33.053480  مصطفى حجازي و حمادة حلمي
# 3   1.695504 -78.221701            Hotel San Jose
# 4 -24.988328 -56.252078                 LB Vy'aha

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
<dt>Weather</dt><dd>{Current Description}</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations,
                                dissipating=False,max_intensity=300,point_radius=4)
marker_layer = gmaps.marker_layer(locations,info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
vacation_df
# Out:
#     Unnamed: 0                    City Country  Max Temp Current Description  \
# 0            8     Province du Boulgou      BF    77.288    scattered clouds
# 1           14             Andranomena      MG    74.876       broken clouds
# 2           22                Kom Ombo      EG    72.608       broken clouds
# 3           42                San José      CO    71.042          light rain
# 4           50                  Mbutuý      PY    70.898     overcast clouds
# 5           54          Ferkessédougou      CI    75.830    scattered clouds
# 6           59                  Ndjolé      GA    73.310     overcast clouds
# 7           61       Minţaqat al Maţār      AE    72.266           clear sky
# 8           70               Boa Vista      BR    80.816    scattered clouds
# 9           91                Itaguaru      BR    71.024          light rain
# 10         107                 Ladário      BR    75.272     overcast clouds
# ...

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[(vacation_df['City'] == 'Itaguaru')]
vacation_end = vacation_df.loc[(vacation_df['City'] == 'Itaguaru')]
vacation_stop1 = vacation_df.loc[(vacation_df['City'] =='Tacaratu')]
vacation_stop2 = vacation_df.loc[(vacation_df['City'] =='Passagem Franca')]
vacation_stop3 = vacation_df.loc[(vacation_df['City'] =='Ladário')]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start[['Lat','Lng']].to_numpy()
end = vacation_end[['Lat','Lng']].to_numpy()
stop1 = vacation_stop1[['Lat','Lng']].to_numpy()
stop2 = vacation_stop2[['Lat','Lng']].to_numpy()
stop3 = vacation_stop3[['Lat','Lng']].to_numpy()

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

fig = gmaps.figure()
vacation_itenerary = gmaps.directions_layer(start[0],end[0],waypoints=[stop1[0],stop2[0],stop3[0]],travel_mode = 'DRIVING'or'BICYCLING'or'WALKING')
fig.add_layer(vacation_itenerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start,vacation_stop1,vacation_stop2,vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    Unnamed: 0             City Country  Max Temp Current Description  \
# 0          91         Itaguaru      BR    71.024          light rain
# 1         127         Tacaratu      BR    74.408     overcast clouds
# 2         169  Passagem Franca      BR    76.820       broken clouds
# 3         107          Ladário      BR    75.272     overcast clouds
#
#          Lat        Lng                         Hotel Name
# 0 -15.787021 -49.816193            Trindade atlético clube
# 1  -9.124235 -38.212762                      Casa de Pedro
# 2  -6.159287 -43.758649                       Hotel Brasil
# 3 -19.392964 -57.036137  Pousada Arara Azul - Pantanal sul

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
<dt>Weather</dt><dd>{Current Description}</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations,
                                dissipating=False,max_intensity=300,point_radius=4)
marker_layer = gmaps.marker_layer(locations,info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
